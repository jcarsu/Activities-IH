# %% [markdown]
# Instructions
#
# Read the three files into python as dataframes
#
# Show the DataFrame's shape.
#
# Standardize header names.
#
# Rearrange the columns in the dataframe as needed
#
# Concatenate the three dataframes
#
# Which columns are numerical?
#
# Which columns are categorical?
#
# Understand the meaning of all columns
#
# Perform the data cleaning operations mentioned so far in class
#
#     1. Delete the column education and the number of open complaints from the dataframe.
#     2. Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.
#     3. Check for duplicate rows in the data and remove if any.
#     4. Filter out the data for customers who have an income of 0 or less.

# %%
import pandas as pd

# %% [markdown]
# 1. Read the three files into python as dataframes

# %%
df=pd.read_csv('file1x.csv')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# 2. Show the DataFrame's shape

# %%
df.shape
# Out:
# (4008, 11)

# %% [markdown]
# 3. Standardize header names

# %%
df.columns = map(str.lower, df.columns)
df
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2=pd.read_csv('file2x.csv')
df2
# Out:
#     Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# ...

# %%
df2.shape
# Out:
# (996, 11)

# %%
df2.columns = map(str.lower, df2.columns)
df2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints  total claim amount  \
# ...

# %% [markdown]
# 4. Rearrange the columns in the dataframe as needed

# %%
df2=df2[['customer','st','gender','education','customer lifetime value','income','monthly premium auto','number of open complaints','policy type','vehicle class','total claim amount']]
df2
# Out:
#     customer          st gender education customer lifetime value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly premium auto number of open complaints     policy type  \
# ...

# %%
df3=pd.read_csv('file3x.csv')
df3
# Out:
#      Customer       State  Customer Lifetime Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly Premium Auto  Number of Open Complaints  \
# ...

# %%
df3.shape
# Out:
# (7070, 11)

# %%
df3.columns = map(str.lower, df3.columns)
df3
# Out:
#      customer       state  customer lifetime value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly premium auto  number of open complaints  \
# ...

# %%
df3=df3[['customer','state','gender','education','customer lifetime value','income','monthly premium auto','number of open complaints','policy type','vehicle class','total claim amount']]
df3
# Out:
#      customer       state gender             education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       customer lifetime value  income  monthly premium auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %% [markdown]
# 5. Concatenate the three dataframes

# %%
dfc= pd.concat([df,df2,df3], axis=0)

# %%
dfc
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316         NaN      M              Bachelor
# 7066  PK87824         NaN      F               College
# 7067  TD14365         NaN      M              Bachelor
# 7068  UP19263         NaN      M               College
# 7069  Y167826         NaN      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
dfc.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer lifetime value       object
# income                       float64
# monthly premium auto         float64
# number of open complaints     object
# policy type                   object
# vehicle class                 object
# total claim amount           float64
# state                         object
# dtype: object

# %% [markdown]
#     1. Delete the column education and the number of open complaints from the dataframe

# %%
dfc
# Out:
#      customer          st gender customer lifetime value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316         NaN      M             23405.98798  71941.0
# 7066  PK87824         NaN      F             3096.511217  21604.0
# 7067  TD14365         NaN      M             8163.890428      0.0
# 7068  UP19263         NaN      M             7524.442436  21941.0
# 7069  Y167826         NaN      M             2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
#     2. Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type

# %%
dfc['customer lifetime value'].values
# Out:
# array([nan, '697953.59%', '1288743.17%', ..., 8163.890428, 7524.442436,
#        2611.836866], dtype=object)

# %%
#Manera 1 de quitar los porcentajes
dfc.replace('%','')
pd.to_numeric(dfc['customer lifetime value'], errors='coerce')
# Out:
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
#             ...
# 7065    23405.987980
# 7066     3096.511217
# 7067     8163.890428
# 7068     7524.442436
# 7069     2611.836866
# Name: customer lifetime value, Length: 12074, dtype: float64

# %%
dfc['customer lifetime value']=pd.to_numeric(dfc['customer lifetime value'], errors='coerce')

# %%
dfc.dtypes
# Out:
# customer                    object
# st                          object
# gender                      object
# customer lifetime value    float64
# income                     float64
# monthly premium auto       float64
# policy type                 object
# vehicle class               object
# total claim amount         float64
# state                       object
# dtype: object

# %%
num_de_porcen= 0
for i in range (len(dfc['customer lifetime value'])):
    if dfc['customer lifetime value'].str.contains('%').iloc[i]==True: num_de_porcen+=1
num_de_porcen
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_222496\1272956782.py in <module>
#       1 num_de_porcen= 0
#       2 for i in range (len(dfc['customer lifetime value'])):
# ----> 3     if dfc['customer lifetime value'].str.contains('%').iloc[i]==True: num_de_porcen+=1
#       4 num_de_porcen
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# ~\anaconda3\lib\site-packages\pandas\core\accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
#     181             return self._accessor
# --> 182         accessor_obj = self._accessor(obj)
# ...

# %% [markdown]
#     3. Check for duplicate rows in the data and remove if any

# %%
duplicate_rows = dfc[dfc.duplicated()]

# %%
duplicate_rows
# Out:
#      customer          st gender  customer lifetime value   income  \
# 1072      NaN         NaN    NaN                      NaN      NaN
# 1073      NaN         NaN    NaN                      NaN      NaN
# 1074      NaN         NaN    NaN                      NaN      NaN
# 1075      NaN         NaN    NaN                      NaN      NaN
# 1076      NaN         NaN    NaN                      NaN      NaN
# ...       ...         ...    ...                      ...      ...
# 4006      NaN         NaN    NaN                      NaN      NaN
# 4007      NaN         NaN    NaN                      NaN      NaN
# 0     GS98873     Arizona      F                      NaN  16061.0
# 1     CW49887  California      F                      NaN  79487.0
# 2     MY31220  California      F                      NaN  54230.0
#
#       monthly premium auto    policy type  vehicle class  total claim amount  \
# 1072                   NaN            NaN            NaN                 NaN
# ...

# %%
dfc.drop_duplicates()
# Out:
#      customer          st gender  customer lifetime value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F                      NaN      0.0
# 2     AI49188      Nevada      F                      NaN  48767.0
# 3     WW63253  California      M                      NaN      0.0
# 4     GA49547  Washington      M                      NaN  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316         NaN      M             23405.987980  71941.0
# 7066  PK87824         NaN      F              3096.511217  21604.0
# 7067  TD14365         NaN      M              8163.890428      0.0
# 7068  UP19263         NaN      M              7524.442436  21941.0
# 7069  Y167826         NaN      M              2611.836866      0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
#     4. Filter out the data for customers who have an income of 0 or less.

# %%
dfc[(dfc['income']<100)]
# Out:
#      customer          st gender  customer lifetime value  income  \
# 0     RB50392  Washington    NaN                      NaN     0.0
# 1     QZ44356     Arizona      F                      NaN     0.0
# 3     WW63253  California      M                      NaN     0.0
# 7     CF85061     Arizona      M                      NaN     0.0
# 10    SX51350  California      M                      NaN     0.0
# ...       ...         ...    ...                      ...     ...
# 7059  WZ45103         NaN      F              5678.050167     0.0
# 7061  RX91025         NaN      M             19872.262000     0.0
# 7062  AC13887         NaN      M              4628.995325     0.0
# 7067  TD14365         NaN      M              8163.890428     0.0
# 7069  Y167826         NaN      M              2611.836866     0.0
#
#       monthly premium auto     policy type  vehicle class  total claim amount  \
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
